# %% [markdown]
# # Неделя 1. Понедельник

# %% [markdown]
# ## Теория вероятностей

# %% [markdown]
# ##### 1. Доля клиентов, которые проявляют спрос на продукт A, составляет 25%, доля клиентов, которые проявляют спрос на продукт B, составляет 15%, а доля клиентов, которые не проявляют спрос ни на один из продуктов, составляет 70%. Какая доля клиентов проявляется спрос как на продукт А так и на продукт B

# %% [markdown]
# #Совместные и несовместные события.
# P(A∪B)=P(A)+P(B)−P(A∩B)
# 10%

# %% [markdown]
# ##### 2. Из 100 туристов, выехавших в заграничное путешествие, 10 человек не знают ни немецкого, ни французского языков, 76 человек знают немецкий и 83 – французский. Сколько туристов знают оба эти языка?

# %% [markdown]
# P(A∪B)=P(A)+P(B)−P(A∩B)
# 0.9 = 0.76 + 0.83−P(A∩B)
# знают оба языка 69 человек

# %% [markdown]
# ##### 3. Вероятность хотя бы одного попадания в цель при трех выстрелах равна $0.973$. Найти вероятность попадания в цель при одном выстреле.

# %% [markdown]
# 1)Вероятность непопадания при одном выстреле = 1-p
# Вероятность непопадания при трех выстрелах = (1-p)³
# 2)Вероятность хотя бы одного попадания = 1 - вероятность ни одного попадания
# 3)0.973 = 1 - (1-p)³
# 4)0.973 = 1 - (1-p)³
# (1-p)³ = 1 - 0.973
# (1-p)³ = 0.027
# 1-p = ∛0.027
# 1-p = 0.3
# p = 1 - 0.3
# p = 0.7
#
# 70% вероятность попадания при одном выстреле

# %% [markdown]
# ##### 4. Три разные модели машинного обучения пытаются независимо друг от друга предсказать купит ли человек у нас товар после увиденной рекламы. Вероятности правильно определить (купит/не купит) $0.8$, $0.7$ и $0.6$ соответственно. Найдите вероятность того, что хоты бы одна модель правильно определит

# %% [markdown]
# 1)все три модели ошибаются, а затем вычесть из 1. (1- 0.8)*( 1- 0.7)*(1- 0.6) = 0.2 * 0.3* 0.4 = 0.024
# 2) Теперь находим вероятность того, что хотя бы одна модель сделает правильное предсказание:
# 1 - 0.024 = 0.976
# 97.6

# %% [markdown]
# ##### 5. В двух урнах находится соответственно 4 и 5 белых и 6 и 3 чёрных шаров. Из каждой урны наудачу извлекается один шар, а затем из этих двух наудачу берется один. Какова вероятность, что это будет белый шар?

# %% [markdown]
# в одной урне 4белых и 6черных, вторая урна 5белых и 3 черных
#
# print((4/10 * 5/8)*1) # - оба (100)
# print((4/10 * 3/8)*0.5) # - б/ч (50)
# print((6/10 * 5/8) * 0.5) # - ч/б (50)
# print((6/10 * 3/8) *0) # - ч/ч (0)
#
# все скалдываем и получаем 51.25%

# %% [markdown]
# # 👥
# Если ты выполнил 6 задач, то сверься с коллегами: обсудите результаты и обратите внимание на ошибки, если они были!

# %% [markdown]
# ##### 6. Чему равна вероятность выпадения двух шестерок на двух и гральных костях, если сумма выпавших очков четна?

# %% [markdown]
# 1/18

# %% [markdown]
# ##### 7. Наша компания занимается поставками продуктов в рестораны. У нас есть три страты ресторанов:
# 1. Рестораны, которые активно продвигают концепцию органической и натуральной пищи, вероятность, что такое ресторан выберет нас в качестве поставщика равна 0.6
# 2. Рестораны, специализирующиеся на высококлассной гастрономии и эксклюзивных ингредиентах, вероятность, что такой ресторан выберет нас в качестве поставщика, составляет 0.5.
# 3. Рестораны, которые ставят перед собой задачу обеспечения оптимального соотношения цены и качества продуктов, вероятность, что такой ресторан выберет нас в качестве поставщика, составляет 0.7
#
# Доля ресторанов каждой из страт $\dfrac{6}{15}, \dfrac{4}{15}, \dfrac{5}{15}$ соответственно.
#
# Нас выбрали в качестве поставщика, к какой страте вероятнее всего принадлежал ресторан? Какова вероятность?

# %% [markdown]
# решаем деревом
# сначала перемножаем потом складываем и находим общую вероятность выбора 0.606
# далее дели вероятность каждого на общую
# получается у первого 0.39, у второго 0.22 у третьего 0.385

# %% [markdown]
# ##### 8. За свой многолетний опыт общения с пассажирами поездов коммивояжер Джек заметил, что только 30% всех пассажиров во время поездки не употребляют пищу перед сном, зато среди них только 15% ночью сильно храпят. Отправляясь в очередную командировку, Джек взял билет в двухместное купе, надеясь отоспаться и не видеть жующего человека. Какова вероятность, что ему не повезет?

# %% [markdown]
# P(A∪B)=P(A)+P(B) (P(A∪B)=P(A)+P(B)−P(A∩B) не учитывваем последнее так как у нас вероятность храпа а другие все равно едят)
# 0.7 + 0.045 = 0.745
# вероятность 74.5 %

# %% [markdown]
# <img src="https://icons.iconarchive.com/icons/icons8/windows-8/256/Programming-Github-icon.png" width=32 /> Пора сохранить изменения для __github__.
#
# 1. Перейди в командной строке в папку, в которой расположен этот нотбук.
# 2. Выполни команду `git add .`
# 3. Выполни команду `git commit -m "probability tasks 13 completed"`
# 4. Выполни команду `git push`

# %% [markdown]
# ##### 9. Известно, что 5% мужчин и 0.25% женщин дальтоники.
#
# * Какова вероятность того, что наугад выбранный человек дальтоник, если выбор производится из группы, содержащей равное число мужчин и женщин?

# %% [markdown]
# P(D) = P(D|M) × P(M) + P(D|W) × P(W)
# 2.625% вероятность что выбранный человек дальтоник

# %% [markdown]
# * Если в условиях предыдущего примера случайно выбранный человек оказался дальтоником, какова вероятность, что это мужчина?

# %% [markdown]
# 0.025(вероятность что будет мужчина дальтоник)/ 0.2625(вероятность одного дальтоника из всех) = 0.9523
# 95.23%

# %% [markdown]
# ##### 10. В ресторане есть 25 столов, из которых 5 являются столиками с самым красивым видом на город. Посетители ресторана подходят к столам один за другим по очереди. Правила ресторана таковы, что столик для гостя выделяется случайным образом. У кого больше вероятность занять столик с прекрасным видом: у того, кто подошел первым, или у того, кто подошел вторым? Почему?

# %% [markdown]
# используем формулу полной вероятности
# вероятность что первый посетитель займет место у окна 5/25 = 20%
#
#
# P(A) = Σ P(A|Bᵢ) × P(Bᵢ) #в зависимомти от первого события
# P₂ = P(A|B₁) × P(B₁) + P(A|B₂) × P(B₂)
# P₂ = 4/24 × 5/25 + 5/24 × 20/25
# P₂ = 0.2
# 20%
# вероятность одинаковая

# %% [markdown]
# ##### 11. Исходя из принципа не класть все яйца в одну корзину, Джек положил 30% своих свободных средств положил в сбербанк, 30% в банк "Форлох", а 40% отдал брату мужа сестры двоюродного деверя. В конце года средства, положенные в сбербанк, выросли на 10%, в банк “Форлох” на 1%, а родственник оказался настолько честным, что вернул все полностью и еще обещал как-нибудь при случае зайти в гости с подарком. Насколько процентов выросли средства Джека?

# %% [markdown]
# > ответ тут

# %% [markdown]
# ##### 12. Две фабрики выпускают одинаковые стекла для автомобильных фар. Первая фабрика выпускает 45% этих стекол, вторая – 55%. Первая фабрика выпускает 3% бракованных стекол, а вторая – 1%.
# Найдите вероятность того, что бракованное стекло выпущено второй фабрикой.

# %% [markdown]
# > ответ тут

# %% [markdown]
# ##### 13. Астрономический объект, за которым ведется наблюдение, может находиться в одном из двух состояний: $Н1$ или $Н2$. Априорные вероятности этих состояний $P(Н1) = 0.6$, $Р(Н2) = 0.4$. Наблюдение ведется независимо двумя обсерваториями. Первая обсерватория обычно дает правильные сведения о состоянии наблюдаемого объекта в 90% случаев, а в 10% ошибается; вторая дает правильные сведения в 80% случаев, а в 20% ошибается. Первая обсерватория сообщила, что объект находится в состоянии $Н1$, а вторая – что в состоянии $Н2$. Найти апостериорную вероятность состояния $Н1$.

# %% [markdown]
#  0.9*0.2 = 0.18
#  0.8*0.1= 0.08
#  0.18*0.6 + 0.4*0.08 = 0.14
#
#  P(A|H1) = 0.6*0.18/0.14 = 0.7714
#  77.14%

# %% [markdown]
# ❓ Что такое апостериорная вероятность?

# %% [markdown]
# > ответ тут

# %% [markdown]
# ##### 14. При расследовании преступления, совершённого на автозаправочной станции (АЗС), было установлено, что поток автомобилей, проезжающих мимо АЗС, состоит на 60% из грузовых и на 40% из легковых автомобилей. По показаниям свидетелей, во время совершения преступления на АЗС находился автомобиль. Известно, что вероятность заправки грузового автомобиля равна 0,1, легкового автомобиля — 0,3.
# Найти вероятность того, что во время совершения преступления на АЗС находился:
# * грузовой автомобиль

# %% [markdown]
# P(A) = Σ P(A|Bᵢ) × P(Bᵢ)
# вероятность грузовой 0.6 * 0.1 = 0.06
# вероятность  легковой 0.4*0.3 = 0.12
# полная вероятность = 0.18
# гр= 0.06 / 0.18 = 1/3 = 33%

# %% [markdown]
# * легковой автомобиль

# %% [markdown]
# 0.12/ 0.18 = 0.66

# %% [markdown]
# ❓Ты вычислил две вероятности. Что это за вероятности? Как они называются?

# %% [markdown]
# обе апостеорные, вероятность с учетом новых дополнительных данных

# %% [markdown]
# ##### 15. Вероятность того, что недельный оборот торговца мороженым превысит 2 000 руб. при солнечной погоде равна 80%, при переменной облачности — 50%, а при дождливой погоде — 10%. Найти вероятность того, что на следующей неделе оборот превысит 2 000 руб., если вероятность солнечной погоды в данное время года составляет 20%, вероятность переменной облачности и вероятность дождливой погоды — по 40%.

# %% [markdown]
# полная вероятность равно 40%

# %% [markdown]
# ##### 16. В казино в Блэкпуле есть два игровых автомата: в первом из них шанс выигрыша составляет 10%, а в другом - в 20%. Очевидно, вы хотели бы играть на машине, которая выплачивает в 20% случаев, но вы не знаете, какая из двух машин более щедрая. Таким образом, вы принимаете следующую стратегию: изначально вы предполагаете, что две машины с равной вероятностью будут щедрой машиной. Затем вы случайным образом выбираете одну из двух машин и кладете в нее монету. Учитывая, что вы проиграли первую ставку, оцените вероятность того, что выбранный вами автомат оказался более "щедрым".

# %% [markdown]
# P(A|L) = P(L|A) × P(A) / P(L)
# полная вероятность проигрыша = 0.85
# вероятность выигрыша на щедром автомате = 0.4
# вероятность щщедрого автомата = 47%

# %% [markdown]
# ##### 17. M&M – шоколадное драже, поверхность которого окрашена в разные цвета. Компания «Марс» (Mars, Inc.) изготавливает это драже, время от времени меняя цвета. В 1995 году драже окрашивались в синий цвет. До этого пакетик M&M содержал драже следующих цветов: 30% коричневых, 20% желтых, 20% красных, 10% зеленых, 10% оранжевых и 10% желто-коричневых. В дальнейшем цвета драже были изменены следующим образом: 24% синих, 20% зеленых, 16% оранжевых, 14% желтых, 13% красных, 13% коричневых. Допустим, у моего приятеля было два пакетика M&M. Один пакетик 1994 года выпуска, а другой – 1996-го. Не сообщив, какой пакетик какого года выпуска, мой приятель дал мне по одному драже из каждого. Одно драже было желтым, другое – зеленым. Какова вероятность, что желтое драже было из пакетика 1994 года выпуска?
#
# ### ‼️
# > В этой задаче может быть несколько путей рассуждения. Обязательно зафиксируй словами, как ты рассуждал, и обсуди с коллегами.
# ### 👥

# %% [markdown]
# есть два варианта вытаскивае желтоу 94 и зеленое 96 или желтое 96 и зеленое 94
# если будет вервый вариант то вероятность 0.04
# если второй вариант то вероятность 0.014
# 0.04 / (0.04+0.014) = 74%
# вероятность что желтое дражже  75%

# %% [markdown]
# ##### 18. Три экзаменатора принимают экзамен по некоторому предмету у группы в 30 человек, причем первый опрашивает 6 студентов, второй — 3 студентов, а третий — 21 студента (выбор студентов производится случайным образом из списка). Отношение трех экзаменаторов к слабо подготовившимся различное: шансы таких студентов сдать экзамен у первого преподавателя равны 40%, у второго — только 10%, у третьего — 70%.
#
# * Найти вероятность того, что слабо подготовившийся студент сдаст экзамен.

# %% [markdown]
# 0.58

# %% [markdown]
# * Пусть известно, что студент не сдал экзамен, т.е. получил оценку «неудовлетворительно». Кому из трех преподавателей вероятнее всего он отвечал?

# %% [markdown]
# ВЕроятней всего сдавал 3 преподавателю 50%
# второму 21%
# первом  28%

# %% [markdown]
# ##### 19. Из 100 человек студентов, сдававших сессию, 48 человек сдали экономику, 42 студента – математику и 37 человек – логику. По экономике или математике сдали экзамен 76 человек, по экономике или логике также 76 человек, а по математике или логике – 66 человек.
#
# * Сколько человек сдали хотя бы один экзамен, если все три предмета сдали 5 человек?

# %% [markdown]
# всего сдали  хотя бы 1 экзамен 96 чел

# %% [markdown]
# * Сколько человек не сдали ни одного экзамена?

# %% [markdown]
# формула включения и исключения
# не сдали ниодного экзамена 4 чел

# %% [markdown]
# * Сколько человек сдали только один экзамен по логике?

# %% [markdown]
# 37 - 9 - 13 + 5 = 20

# %% [markdown]
# <img src="https://icons.iconarchive.com/icons/icons8/windows-8/256/Programming-Github-icon.png" width=32 /> Сохрани файл для __github__.
#
# 1. Перейди в командной строке в папку, в которой расположен этот нотбук.
# 2. Выполни команду `git add .`
# 3. Выполни команду `git commit -m "probability tasks completed"`
# 4. Выполни команду `git push`
